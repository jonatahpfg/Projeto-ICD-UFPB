# %% [markdown]
# <a href="https://colab.research.google.com/github/jonatahpfg/Projeto-ICD-UFPB/blob/main/C%C3%B3pia_de__Original_de_Projeto_ICD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **OBJETIVOS**
#
# O objetivo desse projeto é realizar uma análise das características musicais de diferentes canções. Isso, identificando padrões e investigando como essas características evoluíram ao longo do tempo. De maneira que, possamos com os resultados obtidos relacionados com contextos sociais que, muitas vezes, nem paramos para pensar, porém, fazem parte do imaginário da sociedade criar hipóteses.
#
# Ao mergulhar nos dados e explorar as características musicais, estaremos em busca de insights significativos, esperamos elucidar informações interessantes que possam surpreender o leitor, fornecendo uma perspectiva aprofundada sobre a dinâmica da música e seu impacto na cultura e na sociedade.

# %% [markdown]
# # **Dados**
#
# Descrição do primeiro dataset (History of Rock (1950-2020):
# Esse dataset possui 5.484 linhas e 18 colunas, sendo cada linha uma determinada música, a qual tem suas características definidas nas colunas correspondentes.
# Abaixo é descrito o que cada coluna significa:
#
# ●	“index”: índice;
#
# ●	“name”: nome da música;
#
# ●	“artist”: nome do artista;
#
# ●	“release_date”: ano em que a música foi lançada;
#
# ●	“length”: duração da música em minutos;
#
# ●	“popularity”: a popularidade da faixa (o valor estará entre 0 e 100, sendo 100 o mais popular);
#
# ●	“danceability”: descreve como uma faixa é adequada para dançar com base em uma combinação de elementos musicais, incluindo tempo e ritmo;
#
# ●	“acousticness”: uma medida de confiança de 0,0 a 1,0 se a faixa é acústica;
#
# ●	“danceability”: descreve como uma faixa é adequada para dançar com base em uma combinação de elementos musicais, incluindo tempo e ritmo;
#
# ●	“energy”: uma medida de 0,0 a 1,0 e representa uma medida perceptiva de intensidade e atividade. Normalmente, as faixas energéticas são mais perto de 1;
#
# ●	“instrumentalness”: prevê se uma faixa não contém vocais. Quanto mais próximo o valor da instrumentalidade estiver de 1, maior é;
#
# ●	“key”: A chave geral estimada da faixa. Os inteiros são mapeados para as notas usando a notação padrão da classe de notas;
#
# ●	“liveness”: detecta a presença de uma audiência na gravação. Valores mais altos de vivacidade representam uma presença maior dessa;
#
# ●	“loudness”: o volume geral de uma faixa em decibéis (dB);
#
# ●	“speechiness”: detecta a presença de palavras faladas em uma faixa. Valores acima de 0,66 descrevem faixas que provavelmente são;
#
# ●	“tempo”: O andamento geral estimado de uma faixa em batidas por minuto (BPM);
#
# ●	“time_signature”: Uma fórmula de compasso geral estimada de uma faixa;
#
# ●	“valence”: Uma medida de 0,0 a 1,0 que descreve a positividade musical transmitida por uma faixa.
#
#
#
# Descrição do segundo dataset (Músicas de 1950 até 2019):
# Esse dataset possui 28.372 linhas e 31 colunas, sendo cada linha uma determinada música, a qual tem suas características definidas nas colunas correspondentes.
# Abaixo é descrito o que cada coluna significa:
# ●	“artist_name”: Indica o artista da música;
#
# ●	“track_name”: Indica o título da música;
#
# ●	“release_date”: Indica o ano de lançamento da música;
#
# ●	“genre”: Indica o gênero musical da múscia;
#
# ●	“lyrics”: Letra da música;
#
# ●	“len”: Indica quantas palavras tem em cada música;
#
# ●	“dating”: Índice do quanto a música é ligada ao assunto namoro;
#
# ●	“violence”: Índice do quanto a música fala sobre violência;
#
# ●	“world/life”: Índice do quanto a música fala sobre a natureza;
#
# ●	“night/time”: Índice do quanto a música fala sobre o período noturno;
#
# ●	“shake the audience”: Índice do quanto a música é capaz de movimentar a audiência;
#
# ●	“family/gospel”: Índice do quanto a música fala sobre família e evangelho;
#
# ●	“romantic”: Índice do quanto a música fala sobre romance;
#
# ●	“communication”: Índice do quanto a música é comunicativa na sua letra;
#
# ●	“obscene”: Índice do quanto a música é  obscena;
#
# ●	“music”: Índice do quanto a música é considerada musical;
#
# ●	“movement/places”: Índice do quanto a música traz a sensação de movimento;
#
# ●	“light/visual perceptions”: Índice do quanto a música descreve percepções visuais;
#
# ●	“family/spiritual”: Índice do quanto a música fala sobre assuntos espirituais;
# ●	“like/girls”: Índice do quanto a música é considerada feminina;
#
# ●	“sadness”: Índice do quanto a música é considerada triste;
#
# ●	“danceability”: Índice do quanto a música é fácil de ser dançada;
#
# ●	“loudness”: A altura da música;
#
# ●	“acousticness”: Índice do quanto a música é acústica;
#
# ●	“instrumentalness”: Índice do quanto a música é instrumental;
#
# ●	“valence”: Índice do quanto a música é positiva e alegre;
#
# ●	“energy”: Índice do quanto a música é energética;
#
# ●	“topic”: Indica o assunto da música;
#
# ●	“age”: Índice do quanto a música fala sobre a idade das pessoas.
#
#
# Descrição do terceiro dataset (500 melhores álbuns de todos os tempos da Rolling Stone):
# Esse dataset possui 500 linhas e 6 colunas, sendo cada linha um determinado álbum, a qual tem suas características definidas nas colunas correspondentes.
# As colunas são:
#
# ●	“Position on the list”: Posição na lista;
#
# ●	“Year of release”: Ano de lançamento;
#
# ●	“Album name”: Nome do álbum;
#
# ●	“Artist name”: Nome do artista;
#
# ●	“Genre name”: Nome do gênero;
#
# ●	“Subgenre name”: Nome do subgênero.

# %% [markdown]
# # **INÍCIO DAS EXPLORAÇÕES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dfalbum = pd.read_csv("https://raw.githubusercontent.com/jonatahpfg/Trabalho-ICD-UFPB/main/arquivos_csv/albumlist.csv", encoding='latin1')
df = pd.read_csv("https://raw.githubusercontent.com/jonatahpfg/Trabalho-ICD-UFPB/main/arquivos_csv/history_of_rock.csv", error_bad_lines=False)
df_music = pd.read_csv("https://raw.githubusercontent.com/jonatahpfg/Trabalho-ICD-UFPB/main/arquivos_csv/music.csv")
# Out:
# <ipython-input-109-7b405bfb9a9e>:7: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("https://raw.githubusercontent.com/jonatahpfg/Trabalho-ICD-UFPB/main/arquivos_csv/history_of_rock.csv", error_bad_lines=False)

# %% [markdown]
# A seguir será feita uma análise da quantidade de álbums por ano, entre os 500 melhores(segundo a Revista Rolling Stone.

# %%
album_por_ano = dfalbum.groupby('Year')['Album'].count()

# Cria o gráfico de barras
album_por_ano.plot(kind='bar', figsize=(10, 6))
plt.title('Quantidade de Álbuns por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Álbuns')
plt.show()

# %% [markdown]
# ## **1) Percebe-se um crescimento anormal a partir de 1965, o que será que pode explicar isso? Faremos uma análise de dois períodos, primeiramente de 1965 a 1980 e depois de 1955 para 1964.**

# %%
dfalbum_filtro_tempo = dfalbum[(dfalbum['Year'] >= 1965) & (dfalbum['Year'] <= 1980)]
generos_desejados = ['Rock','Jazz', 'Pop', 'Blues', 'Folk', 'Punk', 'Electronic', 'Reggae']

# Filtra o DataFrame apenas para os gêneros desejados
df_generos_desejados = dfalbum_filtro_tempo[dfalbum_filtro_tempo['Genre'].isin(generos_desejados)]

genero_contagem = dfalbum_filtro_tempo['Genre'].value_counts()

# Calcula a porcentagem de cada estilo musical em relação ao total de ocorrências
total_ocorrencias = genero_contagem.sum()
genero_porcentagem = (genero_contagem / total_ocorrencias) * 100

# Seleciona os 10 estilos musicais mais frequentes
n = 10
genero_porcentagem = genero_porcentagem.head(n)

display(genero_porcentagem)
# Cria o gráfico de barras com as porcentagens
genero_porcentagem.plot(kind='bar', figsize=(10, 6))
plt.title('Distribuição de Estilos Musicais (1965-1980)')
plt.xlabel('Estilo Musical (Gênero)')
plt.ylabel('Porcentagem (%)')
plt.show()
# Out:
# Rock                            60.350877
# Funk / Soul                     10.877193
# Rock, Blues                      3.859649
# Rock, Pop                        3.157895
# Electronic, Rock                 2.807018
# Rock, Folk, World, & Country     2.105263
# Folk, World, & Country           1.754386
# Reggae                           1.754386
# Rock, Funk / Soul                1.403509
# Blues                            1.052632
# Name: Genre, dtype: float64

# %% [markdown]
# Agora faremos a mesma coisa para o período entre 1955 e 1964

# %%
dfalbum_filtro_tempo = dfalbum[(dfalbum['Year'] >= 1955) & (dfalbum['Year'] <= 1964)]
generos_desejados2 = ['Rock','Jazz', 'Pop', 'Blues', 'Folk', 'Punk','Reggae']


df_generos_desejados = dfalbum_filtro_tempo[dfalbum_filtro_tempo['Genre'].isin(generos_desejados2)]

genero_contagem = dfalbum_filtro_tempo['Genre'].value_counts()


total_ocorrencias = genero_contagem.sum()
genero_porcentagem = (genero_contagem / total_ocorrencias) * 100


n = 10
genero_porcentagem = genero_porcentagem.head(n)

display(genero_porcentagem)

genero_porcentagem.plot(kind='bar', figsize=(10, 6))
plt.title('Distribuição de Estilos Musicais (1955-1964)')
plt.xlabel('Estilo Musical (Gênero)')
plt.ylabel('Porcentagem (%)')
plt.show()
# Out:
# Jazz                                   20.0
# Rock                                   12.0
# Jazz, Pop                              12.0
# Blues                                  12.0
# Rock, Blues                             8.0
# Funk / Soul, Blues                      8.0
# Rock, Pop                               8.0
# Funk / Soul                             4.0
# Folk, World, & Country                  4.0
# Funk / Soul, Folk, World, & Country     4.0
# Name: Genre, dtype: float64

# %% [markdown]
# As décadas de 70 e 80 foram períodos de efervescência criativa na indústria fonográfica, impulsionados por diversos fatores. Além dos eventos culturais e sociais, como o movimento pelos direitos civis e a revolução tecnológica, é importante destacar a diversidade de gêneros musicais que surgiram e se consolidaram nessa época. Foi uma era de experimentação e inovação, onde artistas e bandas exploraram novos sons e estilos, resultando em uma grande variedade de álbuns icônicos.
#
# O surgimento de gêneros trouxe uma riqueza de influências musicais e contribuiu para a diversidade da produção fonográfica. Cada um desses estilos tinha suas próprias características distintas e movimentos culturais associados, proporcionando uma ampla gama de opções musicais para os ouvintes.
#
# Além disso, as décadas de 70 e 80 também testemunharam avanços tecnológicos na gravação e produção musical. O surgimento de novos equipamentos, como sintetizadores e gravadores de fita multicanais, permitiu uma maior experimentação sonora e abriu caminho para a criação de novas texturas e arranjos musicais.
#
# A influência cultural dessas décadas também foi imensa. Movimentos como o feminismo, o movimento LGBT e o ativismo político deixaram sua marca na música, refletindo-se em letras engajadas e abordando questões sociais relevantes da época. Essa conexão entre música e contexto social contribuiu para a relevância duradoura de muitos álbuns lançados nessa época.
#
# Portanto, a presença de muitos discos das décadas de 70 e 80 na lista dos 500 melhores discos da Rolling Stone reflete a importância histórica e cultural desses períodos, assim como a influência duradoura que tiveram na indústria musical e na cultura popular. É uma celebração da diversidade e criatividade que permearam a produção fonográfica dessas décadas, consolidando esses álbuns como marcos significativos na história da música. Ou seja, torna-se evidente através dos gráficos que os discos deram um "Boom" próximo dos anos 70, ademais é vísivel que o rock tornou-se líder do mainstream da época, esse aumento na popularidade pode ter levado a uma redução relativa da atenção a outros estilos em critérios de avaliação dos críticos.

# %% [markdown]
# ### **2) Agora vamos avaliar se os críticos representam uma realidade social, analisando se ter um ou mais discos entre os 500 melhores representa que o artista é popular.**

# %% [markdown]
# Então vamos ver a média de popularidade dos artistas com álbuns entre os 500 melhores no dataset com músicas gerais, limitando para aqueles que possuem pelo menos 5 músicas no arquivo.

# %%
artistas_discos = dfalbum['Artist'].unique()

df_musicas_artistas_presentes = df[df['artist'].isin(artistas_discos)]

contagem_musicas_por_artista = df_musicas_artistas_presentes.groupby('artist').size()

# Filtrar apenas os artistas que possuam pelo menos 5 músicas
artistas_com_minimo_musicas = contagem_musicas_por_artista[contagem_musicas_por_artista >= 5 ]

# Filtrar o dataset de músicas para incluir somente os artistas com pelo menos 5 músicas
df_musicas_artistas_presentes_filtrado = df_musicas_artistas_presentes[df_musicas_artistas_presentes['artist'].isin(artistas_com_minimo_musicas.index)]

# Calcular a média de popularidade de cada artista
media_popularidade_por_artista = df_musicas_artistas_presentes_filtrado.groupby('artist')['popularity'].mean()

# Ordenar a média de popularidade por artista em ordem decrescente
media_popularidade_por_artista = media_popularidade_por_artista.sort_values(ascending=False)


media_geral_entre500= media_popularidade_por_artista.mean()


print(f"\nA média de popularidade de artistas com álbuns entre os 500 melhores é {media_geral_entre500}%")
# Out:
# A média de popularidade de artistas com álbuns entre os 500 melhores é 53.44971120667604%

# %% [markdown]
# Com essa váriavel mediamedia_sem_entre500 = df_unido[df_unido['Album'] == 0].mean(), obtemos que a popularidade geral dos artistas sem álbuns entre os 500 é 50,7%(sem limitações impostas a esse dado), já os que possuem ao menos um álbum (com limitações de pelo menos 5 músicas no dataset) tem média de popularidade de 53%.

# %% [markdown]
# Agora vamos categorizar quantos álbuns cada artista possui no dataset, gerando um gráfico.

# %%
#Neste pedaço basicamento separamos a quantidade de álbum
df_album_por_artista = dfalbum.groupby('Artist')['Album'].count()
df_album_por_artista = df_album_por_artista.sort_values(ascending=False)
n_artistas = 30 
album_por_artista_limitado = df_album_por_artista.head(n_artistas)

album_por_artista_limitado.plot(kind='bar', figsize=(10, 6))
plt.title(f'Quantidade de Álbuns por Artista (Top {n_artistas})')
plt.xlabel('Artistas')
plt.ylabel('Quantidade de Álbuns')
plt.show()

# %% [markdown]
# Com essas informações vamos verificar se a quantidade de álbuns entre os 500 melhores é proporcional a popularidade

# %%
df_ajeitado = df[df['popularity'] > 5]
#calcular a média da popularidade agrupada pelos artistas
df_popularidade_media = df_ajeitado.groupby('artist')['popularity'].mean().sort_values(ascending=False)


artistas_com_mais_de_5_musicas = df_ajeitado['artist'].value_counts()[df_ajeitado['artist'].value_counts() > 5].index

#filtrar a popularidade para somente artistas com pelo menos 6 músicas no dataset
df_popularidade_media_filtrada = df_popularidade_media[df_popularidade_media.index.isin(artistas_com_mais_de_5_musicas)]

#filtrar os artistas com mais de 10% de popularidade
df_popularidade_media_filtrada = df_popularidade_media_filtrada[df_popularidade_media_filtrada >10]
#dataframe categorizado 
df_unido = pd.DataFrame({'Artist': df_popularidade_media_filtrada.index, 'popularity': df_popularidade_media_filtrada.values})

#adição dos albuns ao lado dos artistas que estão no top 500
df_unido = df_unido.merge(df_album_por_artista, on='Artist', how='left')





df_unido['Album']= df_unido['Album'].fillna(0)

print("\nUnião da média de popularidade com a quantidade de álbuns por artista:")
display(df_unido)

plt.figure(figsize=(10, 6))
plt.scatter(df_unido['popularity'], df_unido['Album'], s=50, c='blue', alpha=0.5)
plt.xlabel('Popularity')
plt.ylabel('Album')
plt.title('Artist Popularity vs. Album')
plt.grid(True)
plt.show()
# Out:
# União da média de popularidade com a quantidade de álbuns por artista:
#                           Artist  popularity  Album
# 0            My Chemical Romance   71.833333    0.0
# 1               System Of A Down   70.875000    0.0
# 2       Bob Marley & The Wailers   69.625000    3.0
# 3                    Linkin Park   69.235294    0.0
# 4                       Coldplay   67.529412    1.0
# ..                           ...         ...    ...
# 214                   April Wine   30.777778    0.0
# 215                  the feelers   27.555556    0.0
# 216  Black Rebel Motorcycle Club   23.666667    0.0
# 217          Super Furry Animals   22.166667    0.0
# 218                  Max Webster   19.833333    0.0
#
# [219 rows x 3 columns]

# %%
count = (df_unido['Album'] > 0).sum()
total_linhas = df_unido['Album'].count()
procentagem_presença= int(count/total_linhas*100)
print(f"{count} de {total_linhas} artistas que estão entre os mais populares do datset possuem pelo um álbum entre os 500 melhores. Representando {procentagem_presença}% do total")
# Out:
# 94 de 219 artistas que estão entre os mais populares do datset possuem pelo um álbum entre os 500 melhores. Representando 42% do total

# %% [markdown]
# Lembrando que limitamos algumas informações, deixamos somente os artistas que possuem  pelo menos 6 músicas no dataset do spotify, isso para manter uma análise mais sólida da popularidade dos artistas, ademais limitamos também para popularidade superior a 10%.

# %% [markdown]
# Podemos questionar com os dados obtidos se a popularidade dos artistas é um indicador confiável da qualidade de sua música, uma vez que nem todos os artistas populares necessariamente têm álbuns entre os 500 melhores. Isso pode abrir discussões sobre como a qualidade musical é avaliada e reconhecida na indústria da música e na sociedade em geral. Porém, é perceptível que 42% é um número altamente expressivo, provando que de fato eles estão em uma alta prateleira da indústria musical. Além disso, é preciso avaliar que muitas das bandas que possuem álbuns entre os 500 podem não ser tão populares em aplicativos de streaming mas possuírem uma imagem de prestígio no cenário, isso porque alguma delas não possuem estilos tão atuais,com isso, verificaremos essa questão com gráficos de popularidade dos períodos de 1955 a 1964 e 1965 a 1980.

# %%
df_filtro_tempo = df[(df['release_date'] >= 1965) & (df['release_date'] <= 1980)]
df_popularidade_80_ano = df_filtro_tempo.groupby('release_date')['popularity'].mean()
df_popularidade_80= df_popularidade_80_ano.mean()

df_filtro_tempo_55 = df[(df['release_date'] >= 1955) & (df['release_date'] <= 1964)]
df_popularidade_55_ano = df_filtro_tempo_55.groupby('release_date')['popularity'].mean()
df_popularidade_55=df_popularidade_55_ano.mean()

coluna_ano = df['release_date']
contagem_por_ano = coluna_ano.value_counts().sort_index()

coluna_popularidade = df.groupby('release_date')['popularity'].mean()


contagem_por_ano.plot(kind='bar', figsize=(15, 6))
plt.title('Quantidade de músicas por ano')
plt.xlabel('Anos')
plt.ylabel('Quantidade de músicas')
plt.show()

coluna_popularidade.plot(kind='bar', figsize=(15, 6))
plt.title('Popularidade por ano')
plt.xlabel('Anos')
plt.ylabel('Popularidade')
plt.show()


musicas_55 = df[(df['release_date'] >= 1955) & (df['release_date'] <= 1964)]

total_musicas_no_intervalo = musicas_55.shape[0]

musicas_80 = df[(df['release_date'] >= 1965) & (df['release_date'] <= 1980)]

total_musicas_no_intervalo_80= musicas_80.shape[0]

# %%
print(f'O número total de músicas no intervalo de anos 1955 a 1964 é: {total_musicas_no_intervalo}')
print(f'O número total de músicas no intervalo de anos 1965 a 1980 é: {total_musicas_no_intervalo_80}')
print(f"Popularidades respectivas : {df_popularidade_55}% e {df_popularidade_80}%")
# Out:
# O número total de músicas no intervalo de anos 1955 a 1964 é: 127
# O número total de músicas no intervalo de anos 1965 a 1980 é: 1521
# Popularidades respectivas : 53.85152717652718% e 54.0142939548881%

# %% [markdown]
# Podemos analisar os dados apresentados e observar que, embora as porcentagens de popularidade entre os intervalos de anos estejam próximas, há uma diferença significativa no número de músicas em cada período. Enquanto o intervalo de 1955 a 1964 possui apenas 127 músicas, o intervalo de 1965 a 1980 apresenta um número muito maior, com 1521 músicas.
#
# Essa diferença no número de músicas sugere que o período de 1965 a 1980 foi marcado por uma constância mais notável em termos de importantes lançamentos. Isso pode ser interpretado como uma indicação da revolução musical que ocorreu durante esse período. A consistência ao longo desses anos indica uma efervescência criativa e uma diversidade de estilos musicais.
#
# Por outro lado, na análise se a época de 1955 a 1964 tivesse um número de músicas equivalente ao período de 1965 a 1980, provavelmente teríamos uma média de popularidade menor. Isso pode sugerir que a época de 1955 a 1964 foi marcada por uma concentração em estilos específicos.
#
# Além disso, é importante destacar que muitos estilos musicais que surgiram ou eram anteriores  as décadas de 50 e 60 tornaram-se mais nichados em termos de popularidade e reconhecimento ao longo do tempo. Isso ocorreu devido a mudanças nos gostos musicais, evolução da indústria musical e diferentes contextos culturais. É interessante observar como certos estilos que foram altamente populares em seu tempo podem ter perdido destaque posteriormente, enquanto outros estilos emergiram e se tornaram dominantes em diferentes épocas e contextos.
#
# Essa análise nos permite compreender as transformações e tendências musicais ao longo do tempo, evidenciando a importância de levar em consideração não apenas as porcentagens de popularidade, mas também o contexto histórico e cultural.

# %% [markdown]
# ### **3) Portanto, vamos analisar como os estilos sofreram (crescimento/descrescimento) na popularidade ao passar dos anos.**

# %% [markdown]
# Fizemos a interseção de dois datasets musicais, para podermos ter gênero e popularidade tabelados pelas músicas.

# %%
#vamos deixar ambos datasets com letras minúsculas 
df_minusculo = df_ajeitado.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df_music_minusculo = df_music.applymap(lambda x: x.lower() if isinstance(x, str) else x)


df_renomeado = df_minusculo[['name', 'artist', 'popularity']]
df_renomeado = df_renomeado.rename(columns={'name': 'track_name', 'artist': 'artist_name'})

# Combina os dois dataframes e mantém todas as colunas do df_music
resultado = pd.merge(df_renomeado, df_music, on=['track_name', 'artist_name'], how='inner')
resultado = resultado.dropna()

del resultado['Unnamed: 0']
resultado = resultado.drop(resultado[resultado['track_name'] == 'in the waiting line'].index)

popularidade_estilos = resultado.groupby(['genre', 'release_date'])['popularity'].mean().reset_index()
teste = resultado[resultado['genre'] == 'blues']
display(teste)

fig, ax = plt.subplots(figsize=(15,8))
sns.lineplot(data=popularidade_estilos, x='release_date', y='popularity', hue='genre', ax=ax)
ax.set_xlabel('Ano de lançamento')
ax.set_ylabel('Popularidade média')
ax.set_title('Popularidade média de cada estilo musical ao longo dos anos')
plt.show()
# Out:
#                 track_name                        artist_name  popularity  \
# 0        seven nation army                  the white stripes          65
# 17   sunshine of your love                              cream          71
# 33            white rabbit                 jefferson airplane          69
# 35         johnny b. goode                        chuck berry          75
# 42       piece of my heart  big brother & the holding company          68
# ..                     ...                                ...         ...
# 944      my lady's on fire                          ty segall          58
# 945                 finger                          ty segall          48
# 946     i’ll be loving you           the king khan & bbq show          50
# 947         lupine dominus                       thee oh sees          29
# 948        the daily heavy                       thee oh sees          36
#
#      release_date  genre                                             lyrics  \
# ...

# %% [markdown]
# É evidente a constância do Pop, um gênero musical que tem mantido sua popularidade ao longo dos anos. Essa popularidade duradoura pode ser atribuída, em parte, à sua notável capacidade de se adaptar às tendências culturais e musicais em constante mudança. O Pop tem sido capaz de evoluir e incorporar elementos de diferentes estilos musicais, mantendo-se relevante para diferentes gerações.
# No entanto, é importante destacar que a história da música é marcada por mudanças e movimentos cíclicos. Um exemplo disso é o blues e o jazz, estilos musicais que já dominaram as paradas de sucesso em determinado período. Analisando períodos específicos, como 1955 a 1964 e 1965 a 1980, percebe-se que o blues e o jazz perderam espaço devido à chegada massiva do rock nas paradas de sucesso. Essas mudanças refletem as preferências em constante evolução do público e a influência de diferentes movimentos culturais ao longo do tempo.

# %% [markdown]
# ### **4) Partindo dessas ánalises vamos identificar a distribuição  das temáticas tratadas nos estilos musicais.**

# %%
df_caracteristicas_media = df_music.groupby('genre')['violence','shake the audience','romantic', 'obscene', 'sadness', 'energy', 'danceability', 'valence'].mean()
display(df_caracteristicas_media)
# Out:
# <ipython-input-120-24bc5a8f4a60>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_caracteristicas_media = df_music.groupby('genre')['violence','shake the audience','romantic', 'obscene', 'sadness', 'energy', 'danceability', 'valence'].mean()
#          violence  shake the audience  romantic   obscene   sadness    energy  \
# genre
# blues    0.133529            0.018328  0.052506  0.076721  0.113511  0.581534
# country  0.074154            0.011639  0.057473  0.067288  0.165922  0.466350
# hip hop  0.095944            0.020645  0.012611  0.411199  0.036589  0.703236
# jazz     0.110003            0.014681  0.062633  0.097504  0.124067  0.463430
# pop      0.105286            0.019494  0.051458  0.097618  0.142083  0.601097
# reggae   0.143954            0.023416  0.025387  0.140276  0.078312  0.589931
# rock     0.180934            0.018758  0.036810  0.062663  0.133539  0.700954
#
# ...

# %%
df_topic = df_music.groupby(['genre', 'release_date'])['topic'].value_counts().reset_index(name='count')
df_topic.dropna()
sns.scatterplot(data=df_topic, x="release_date", y="count", hue='topic')
# Out:
# <Axes: xlabel='release_date', ylabel='count'>

# %%
df_topic_date = df_music.groupby(['genre'])['topic'].value_counts()

# %%
df_topic_date = df_topic_date.rename('count').reset_index()

# Criar o gráfico de barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='genre', y='count', hue='topic', data=df_topic_date)

# Configurar os rótulos dos eixos x e y
plt.xlabel('Gênero Musical')
plt.ylabel('Contagem de Tópicos')

# Configurar o título do gráfico
plt.title('Contagem de Tópicos por Gênero Musical')

# Exibir o gráfico
plt.show()

# %%
hip_hop_songs = df_music[df_music['genre'] == 'hip hop']


num_obscene_songs = hip_hop_songs[hip_hop_songs['topic'] == 'obscene'].shape[0]
media_obscene_songs = num_obscene_songs / hip_hop_songs.shape[0]
print(media_obscene_songs)
# Out:
# 0.7699115044247787

# %% [markdown]
# É evidente que ao passar dos anos as músicas apresentaram variações em sua temática, em especial o nível obscenidade. Mudanças na sociedade e na cultura ocorreram com as normas e os valores culturais evoluindo. Partindo para o contexto do Hip Hop, no dataset há 904 músicas desse estilo, e a apesar disso, quase de maneira total a temática "obscene" está em evidência, 77% das músicas de Hip Hop são da temática citada. Podemos identificar alguns pontos como possíveis condutores dessas informações. São eles:
#
# Expressão artística e liberdade de expressão: O hip hop é um gênero musical conhecido por sua ênfase na liberdade de expressão e na narrativa das experiências pessoais dos artistas. Alguns artistas podem usar a linguagem obscena como uma forma de expressar emoções intensas, descrever suas realidades ou transmitir mensagens provocativas.
#
# Contexto sociocultural: O hip hop emergiu como um gênero musical em comunidades urbanas que enfrentavam desafios sociais, econômicos e raciais. Muitas vezes, as letras de hip hop refletem a realidade dessas comunidades, abordando questões como pobreza, violência, discriminação e desigualdade. A linguagem obscena pode ser usada para enfatizar e transmitir essas realidades de forma contundente.
#
# Influências da indústria musical e comercialização: A indústria da música muitas vezes busca maximizar a comercialização e o apelo do hip hop. Algumas gravadoras podem incentivar ou promover conteúdo obsceno, pois isso pode gerar mais controvérsia, publicidade e, consequentemente, aumentar a exposição e as vendas.

# %% [markdown]
# **5) Será que algumas características musicais possuem algum relação?**

# %%
sns.lmplot(data=df_music, x='valence', y='danceability', line_kws={'color': 'red'})
plt.show()

# %%
sns.lmplot(data=df_music, x= 'valence', y= 'energy', line_kws={'color': 'red'})
plt.show()

# %% [markdown]
# 1) A relação entre a valência e a danceabilidade pode ser explicada por características musicais e preferências de audição. A valência é uma medida da positividade ou negatividade emocional percebida em uma música, enquanto a danceabilidade é uma medida da capacidade de uma música de ser dançante ou ter uma batida rítmica que incentiva o movimento.
#
# Faixas com alta valência geralmente evocam emoções positivas, como alegria, felicidade ou excitação. Muitas vezes, essas músicas têm uma sonoridade animada, com elementos como melodias alegres, acordes ou batidas rítmicas enérgicas. Essas características musicais podem aumentar a danceabilidade da música, fazendo com que as pessoas se sintam inclinadas a se mover e dançar ao ritmo da música.
#
# 2)As músicas com alta valência geralmente apresentam elementos musicais que contribuem para um alto nível de energia percebido. Isso pode incluir elementos como batidas rápidas e intensas, instrumentação enérgica, vocais expressivos e arranjos musicais dinâmicos. Esses elementos contribuem para uma sensação de intensidade e empolgação na música, resultando em um maior nível de energia percebido.

# %%
sns.lmplot(data=df_music, x= 'valence', y= 'violence', line_kws={'color': 'red'})
plt.show()

# %% [markdown]
# # **Resultados finais**
# Ao longo deste trabalho, realizamos uma análise abrangente dos dados relacionados à música, abordando diferentes aspectos como popularidade, estilos musicais, temáticas e características musicais. A partir dessas análises, podemos chegar a alguns resultados finais.
#
# Em relação ao crescimento anormal a partir de 1965, observamos que as décadas de 70 e 80 foram períodos de efervescência criativa na indústria fonográfica. Diversos fatores, como eventos culturais e sociais, revolução tecnológica e diversidade de gêneros musicais, contribuíram para esse crescimento. A era de experimentação e inovação resultou em uma grande variedade de álbuns icônicos, que se tornaram marcos na história da música.
#
# Quanto à representatividade dos críticos na lista dos 500 melhores discos da Rolling Stone, verificamos que 42% dos artistas mais populares possuem pelo menos um álbum nessa lista. Onde em grande parte deles, ficaram em níveis intermediários e altos de popularidade. Também é importante considerar que a popularidade dos artistas não é necessariamente um indicador confiável da qualidade de sua música, e a avaliação da qualidade musical é um tema complexo e subjetivo.
#
# Ao analisar a distribuição dos estilos musicais ao longo dos anos, identificamos que o Pop tem mantido sua popularidade de forma consistente. No entanto, a história da música é marcada por mudanças e movimentos cíclicos, como a ascensão e queda de estilos como o blues e o jazz. Essas mudanças refletem as preferências do público e a influência de diferentes movimentos culturais ao longo do tempo.
#
# Quanto às temáticas tratadas nas músicas, observamos que ao longo dos anos houve variações significativas. É notável o aumento do uso de temáticas obscenas, especialmente no contexto do Hip Hop. Essa tendência pode ser atribuída à expressão artística, liberdade de expressão, contexto sociocultural e influências da indústria musical e comercialização.
#
# Por fim, identificamos uma relação positiva entre a valência com a danceabilidade e a energia das músicas e negativa com índice de violência. Faixas com alta valência, que evocam emoções positivas, tendem a ser mais dançantes e energéticas. Isso pode ser explicado por características musicais como melodias alegres, batidas enérgicas e arranjos dinâmicos que aumentam a energia percebida das músicas.
#
# Essas análises nos permitem compreender as transformações e tendências musicais ao longo do tempo, considerando o contexto histórico, social e cultural. É importante destacar que a música é uma forma de expressão artística que reflete e influencia a sociedade, e sua apreciação e avaliação envolvem uma combinação de fatores subjetivos e objetivos.

# %% [markdown]
# # **Limitações**
#
# Em evidência, a maior limitação foi não ter a popularidade das músicas no datset (Músicas de 1950 até 2019), visto que ele possui mais 28 mil músicas, o que nos daria uma forte têndencia das variações do mainstream musical. Já no dataset (history of rock) haviam músicas de outros gêneros além do rock, porém não havia a identificação desses gêneros, fazendo com que se tenha a necessidade de mesclar os dois datasets, diminuindo, assim, o espaço amostral.

# %% [markdown]
# # **Melhorias futuras**
#
# O resultado do trabalho foi como o esperado, entretanto como citado nas limitações alguns dados faltaram nos datasets. Com isso, futuramente, a utilização de API's pode ser uma solução para esse problema, podemos utilizar a API tanto do Spotify quanto do Last.fm para obter insights de informações mais direcionadas ao que precisamos.
